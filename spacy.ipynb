# %%
import spacy 
from spacy import displacy
import os
# Out:
# /home/aman/anaconda3/lib/python3.10/site-packages/torch/cuda/__init__.py:107: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0
# 2023-06-05 15:34:26.453235: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-05 15:34:27.347492: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 15:34:28.738150: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2023-06-05 15:34:28.738192: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:168] retrieving CUDA diagnostic information for host: Aman-G3
# 2023-06-05 15:34:28.738201: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:175] hostname: Aman-G3
# 2023-06-05 15:34:28.738243: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:199] libcuda reported version is: 530.41.3
# 2023-06-05 15:34:28.738266: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:203] kernel reported version is: 530.41.3
# 2023-06-05 15:34:28.738272: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:309] kernel version seems to match DSO: 530.41.3

# %%
pwd
# Out:
# '/home/aman/Documents/Tally/DocumentAI/Code'

# %%
os.chdir('/home/aman/Documents/Tally/DocumentAI/Data/texts/')

# %%
file = open(os.listdir()[2])

# %%
data = file.read()

# %%
print(data)
# Out:
# Bill of Supply cum Receipt. Original Copy
# TATA 1MG Technologies Pvt Ltd
# #607, Ground,1st,2nd & 3rd Floor, SOFT. Road, 6th Block, Kormangala,Bangalore- 560095, Karnataka
# “care@1mg.com.
# “Wwww.1mg.com ‘
#
# GSTIN: 29AAACZ8318D1Z6
#
# ‘Serial no. of Invoice:L292223000143565 Date: 21-08-2022
# Details of Receiver (Billed To) Details of Consignee (Shipped To)
#
# Name: Krishnamma Name: Krishnamma
#
# -Addressi 6/5, 1st Floor, 3rd Main 5th’A Cross, Brindavan Layout, LN. Address: 6/5, 1st Floor, 3rd Main Sth A Cross, Brindavan
#
# Reddy Main Road, Vignana Nagar Bangalore, 560037 . wayeut. LN Reddy Main Road, Vignana Nagar Bangalore,
#
# State: Karnataka . .
# State: Karnataka
#
# State Code: 29
# State Code: 29:
#
# GSTIN/Unique ID: -
# GSTIN/Unique ID:
#
# Lab test conducted by TATA 1mg Labs (TATA 1mg Technologies Private Limited) |
#
# ‘S.No. Description Of Services HSN/SAC Code Taxable Value
# a Liver Function Test + Kidney Function Test 999316 199.0
# 2 Diabetes Screening 999316 120.0
# 3 Serum Electrolyte 999316 400.0
# Invoice Total (In Words):Seven Hundred And Nineteen Rupees Only Total 719.0
#
# Terms & Conditions
#
# For. TATA 1MG Technologies Pvt Ltd
# 1, Interest 18% p.a. will be charged if the payment is not made within the stipulated
# time.
# 2. All disputes will be subject to Bangalore Jurisdiction only.
#
# ‘\
# (om
# : ;
# CIN: U74140DL2015PTC279229
#
# PAN: AAACZ8318D Authorised Signatory

# %%
nlpModel = spacy.load("en_core_web_lg") #pretrained models for named entity recognition (NER)

# %%
document = nlpModel(data)

# %%
for entity in document.ents:
    print(entity.text, "->", entity.label_)
# Out:
# Bill -> PERSON
# Technologies Pvt Ltd -> ORG
# #607 -> MONEY
# Ground,1st,2nd & 3rd Floor, SOFT -> ORG
# 6th Block -> FAC
# Kormangala -> GPE
# 560095 -> CARDINAL
# Karnataka -> GPE
# 29AAACZ8318D1Z6 -> CARDINAL
# 21-08-2022 -> DATE
# Consignee -> PERSON
# Krishnamma
#
# -Addressi -> PERSON
# 6/5 -> CARDINAL
# 1st -> ORDINAL
# 3rd -> ORDINAL
# Brindavan Layout -> ORG
# LN -> ORG
# 6/5 -> CARDINAL
# 1st -> ORDINAL
# Main Sth A Cross -> ORG
# Brindavan -> PERSON
# Reddy Main Road -> FAC
# Vignana Nagar -> PERSON
# Bangalore -> GPE
# 560037 -> DATE
# wayeut -> PERSON
# LN Reddy -> ORG
# Main Road -> FAC
# Vignana Nagar -> PERSON
# Bangalore -> GPE
# Karnataka -> GPE
# State -> ORG
# Karnataka -> GPE
# 29 -> CARDINAL
# 29 -> CARDINAL
# GSTIN -> PERSON
# TATA 1mg Labs -> ORG
# TATA 1mg Technologies Private Limited -> ORG
# Description Of Services -> ORG
# HSN -> ORG
# 2 -> CARDINAL
# 999316 -> CARDINAL
# 3 -> CARDINAL
# Serum Electrolyte -> PRODUCT
# 999316 400.0 -> CARDINAL
# 719.0 -> CARDINAL
# Technologies Pvt Ltd -> ORG
# 1 -> CARDINAL
# 18% -> PERCENT
# 2 -> CARDINAL
# Bangalore Jurisdiction -> ORG
# CIN -> ORG
# PAN -> ORG

# %%
displacy.render(document, jupyter=True, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bill
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  of Supply cum Receipt. Original Copy</br>TATA 1MG
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Technologies Pvt Ltd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     #607
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ground,1st,2nd &amp; 3rd Floor, SOFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Road,
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6th Block
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kormangala
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,Bangalore-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     560095
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Karnataka
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>“care@1mg.com.</br>“Wwww.1mg.com ‘</br></br>GSTIN:
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29AAACZ8318D1Z6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br></br>‘Serial no. of Invoice:L292223000143565 Date:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     21-08-2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>Details of Receiver (Billed To) Details of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Consignee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (Shipped To)</br></br>Name: Krishnamma Name:
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Krishnamma
#
# -Addressi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6/5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1st
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  Floor,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3rd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  Main 5th’A Cross,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brindavan Layout
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Address:
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6/5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1st
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  Floor, 3rd
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Main Sth A Cross
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brindavan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br></br>
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reddy Main Road
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vignana Nagar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bangalore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     560037
#     <span style="font-size: 0.8em; font-weight: b

# %%
def predict(imagePath):
