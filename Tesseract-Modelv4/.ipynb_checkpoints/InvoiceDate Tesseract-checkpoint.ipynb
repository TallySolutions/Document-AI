# %%
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import spacy
from spacy import displacy
import pytesseract
from pytesseract import Output
pytesseract.pytesseract.tesseract_cmd="/home/aman/anaconda3/envs/tallyInvoiceParser.env/bin/tesseract"
os.environ['TESSDATA_PREFIX'] = "/home/aman/anaconda3/envs/tallyInvoiceParser.env/share/tessdata"
import import_ipynb
from textPreProcessor import *
from imagePreProcessor import *
from TesseractModify import *
from datetime import datetime
import math
# Out:
# 2023-06-13 17:05:19.553618: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# importing Jupyter notebook from textPreProcessor.ipynb
# Original Date ----> After Processing
#
# 5-12-22
# True
# 2-2-2023
# True
# 5-12-2023
# True
# 5-05-2023
# True
# 5-05-2023
# True
# 10-24-2022
# True
# 10-24-2022
# True
# 22-05-2023
# True
# 21-02-23
# True
# 5-12-22
# True
# 31-08-2022
# True
# importing Jupyter notebook from imagePreProcessor.ipynb
# importing Jupyter notebook from TesseractModify.ipynb

# %%
pwd
# Out:
# '/home/aman/Documents/Tally/Git-Document-AI/Document-AI/Tesseract-Modelv4'

# %%
imagesDir = '/home/aman/Documents/Tally/DocumentAI/Code/Tesseract-Modelv4/Dataset/SampleImages/'

# %%
os.chdir(imagesDir)

# %%
imagePath="11.jpeg"

# %%
image = cv2.imread(imagePath)

# %%
plt.imshow(image)

# %%
preProcessedImage = preProcessImage(imagePath)

# %%
plt.imshow(preProcessedImage)

# %%
data = pytesseract.image_to_data(preProcessedImage, output_type=Output.DATAFRAME)
processData(data)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      block_num  left   top  width  height       conf  \
# 0            2   238   200     92     116  49.230339
# 1            2   426   239    278      66  66.124664
# 2            3   377   319     71      19  87.236626
# 3            3   453   319     52      19  93.294891
# 4            3   509   313    111      23  85.986351
# ..         ...   ...   ...    ...     ...        ...
# 216         10   443  1209     60      51  88.553131
# 217         13  1469  1428    -14      60  77.925272
# 218         16  1271  1638    234      26  96.546208
# 219         18   235  1675    637     232  91.829305
# 220         19   522  1916    413      23  96.433813
#
#                                                   text
# 0                                                    S
# 1                                                pAyYs
# 2                                              #27,2nd
# 3                                               Cross,
# 4                                            MSRamaiah
# ..                                                 ...
# 216                                        Tax% 28.00
# 217                                   2,950 ‘ForDAYS.
# 218                              Authorised Signature
# 219  Terms and Conditions: 1 Allcontents/ charges o...
# 220                             Save Paper Save Earth
#
# [221 rows x 7 columns]

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      block_num  left   top  width  height       conf  \
# 0            2   238   200     92     116  49.230339
# 1            2   426   239    278      66  66.124664
# 2            3   377   319     71      19  87.236626
# 3            3   453   319     52      19  93.294891
# 4            3   509   313    111      23  85.986351
# ..         ...   ...   ...    ...     ...        ...
# 216         10   443  1209     60      51  88.553131
# 217         13  1469  1428    -14      60  77.925272
# 218         16  1271  1638    234      26  96.546208
# 219         18   235  1675    637     232  91.829305
# 220         19   522  1916    413      23  96.433813
#
#                                                   text
# 0                                                    S
# 1                                                pAyYs
# 2                                              #27,2nd
# 3                                               Cross,
# 4                                            MSRamaiah
# ..                                                 ...
# 216                                        Tax% 28.00
# 217                                   2,950 ‘ForDAYS.
# 218                              Authorised Signature
# 219  Terms and Conditions: 1 Allcontents/ charges o...
# 220                             Save Paper Save Earth
#
# [221 rows x 7 columns]

# %%
print(df["text"].to_numpy())
# Out:
# ['S' 'pAyYs' '#27,2nd' 'Cross,' 'MSRamaiah' 'Enclave,' 'Havanur'
#  'Layout,Nagasandra' 'Post,Bangalore' '560073' 'Karnataka' 'Cell'
#  ':9341066551' '~' 'E-Mail' 'ID:' 'dayscoffee2012@qmail.' 'com' '-TIN-'
#  '29481209435,' 'Dated' ':' '30-03-2014' 'GST' 'NO' '>29AAKFD3444R1Z0'
#  'Buyer' 'State' 'Code' ':' '29,' 'KARNATAKA' 'M/s.' 'Tally' 'Solutions'
#  'Pvt' 'Ltd.,' 'PAN:' 'AAKFD3444R.' 'AMR' 'Tech' 'Park,' '2B,' 'Corporate'
#  'Block' 'GST' 'No' '-' '29AAKFD3444R1ZQ' '2nd' 'Floor,' 'Hosur' 'Main'
#  'Road,' 'Bengalooru,' 'Karnataka' 'GST' 'No' ':' '29AAACP7879D1Z0'
#  'State' 'Code:' '29' 'Invoice' '#:-' 'Date:' '__.31stJan-2023' '[sis|'
#  'Taras' '[ewe]' '“ony' 'Uae' '|' 'ate' 'Amt' 'Toa' '[TART' 'Toa' 'Jan-23'
#  'Beans' 'Additional' 'Flavoured' 'tea' '-.Gngr' '&' 'Cardm' '.' '|Assam'
#  '&' 'Plain' 'tea' 'Green' 'Tea' '-' 'Verities' 'Lemon' 'Premix' 'Badam'
#  'Tomato' 'Soup' 'Sugar' 'Wodden' 'Stirrers' 'Horlicks' 'Boost.' 'Milk'
#  '(Nandini)' 'eooc0eocooeoscoCoSo' 'Tax%' '28.00' '2,950' '‘ForDAYS.'
#  'Authorised' 'Signature' 'Terms' 'and' 'Conditions:' '1' 'Allcontents/'
#  'charges' 'of' 'the' 'invoice' 'will' 'be' 'deemed' 'correct' '&'
#  'accepted' 'by' 'you,' 'unless' 'you' 'inform' 'us' 'of' 'any'
#  'discrepancies/' 'disagreement' 'through' 'a' 'signed' 'letter,' 'within'
#  '30' 'days' 'from' 'the' 'date' 'of' 'receipt' 'of' 'invoice,' 'falling'
#  'which' 'it' 'shall' 'be' 'construed' 'that' 'all' 'contents/' 'charges'
#  'indicated' 'in' 'the' 'invoice' 'is' 'in' 'order' '&' 'DAY' 'S' 'ABCTCL'
#  'will' 'not' 'be' 'responsible' 'or' 'liable' 'for' 'any' 'disputes/'
#  'claims' 'received' 'post' 'the' 'said' 'date.' '‘Goods' 'once' 'sold'
#  'cannot' 'be' 'either' 'exchanged' 'or' 'taken' 'back' '‘This'
#  'transaction' 'is' 'subject' 'to' 'Bengalooru' '-' 'Court' 'Jurisdiction'
#  'only.' 'Save' 'Paper' 'Save' 'Earth' 'S pAyYs '
#  '#27,2nd Cross, MSRamaiah Enclave, Havanur Layout,Nagasandra Post,Bangalore 560073 Karnataka Cell :9341066551 ~ E-Mail ID: dayscoffee2012@qmail. com -TIN- 29481209435, Dated : 30-03-2014 GST NO >29AAKFD3444R1Z0 Buyer State Code : 29, KARNATAKA M/s. Tally Solutions Pvt Ltd., PAN: AAKFD3444R. AMR Tech Park, 2B, Corporate Block GST No - 29AAKFD3444R1ZQ 2nd Floor, Hosur Main Road, Bengalooru, Karnataka GST No : 29AAACP7879D1Z0 State Code: 29 Invoice #:- Date: __.31stJan-2023 [sis| Taras [ewe] “ony Uae | ate Amt Toa [TART Toa '
#  'Jan-23 Beans Additional Flavoured tea -.Gngr & Cardm . |Assam & Plain tea Green Tea - Verities Lemon Premix Badam Tomato Soup Sugar Wodden Stirrers Horlicks Boost. Milk (Nandini) '
#  'Tax% 28.00 ' '2,950 ‘ForDAYS. ' 'Authorised Signature '
#  'Terms and Conditions: 1 Allcontents/ charges of the invoice will be deemed correct & accepted by you, unless you inform us of any discrepancies/ disagreement through a signed letter, within 30 days from the date of receipt of invoice, falling which it shall be construed that all contents/ charges indicated in the invoice is in order & DAY S ABCTCL will not be responsible or liable for any disputes/ claims received post the said date. ‘Goods once sold cannot be either exchanged or taken back ‘This transaction is subject to Bengalooru - Court Jurisdiction only. '
#  'Save Paper Save Earth ']

# %%
toDrop = []
for col in df.columns:
    if len(df[col].unique())==1:
        toDrop.append(col)
df.drop(columns=toDrop, inplace=True)

indexesToDrop = []
stopwords=[""]
#stopwords = ["", " ", "  ", "/", ":", "-", ".", ",", "\n", "\t", "\\", "(", ")", "[", "]", "{", "}", "*", "&", "%", "$", "#", "|"]
for index in df.index:
    if df["text"][index] in stopwords:
        indexesToDrop.append(index)   
df.drop(indexesToDrop, inplace=True)

df
# Out:
#      block_num  left   top  width  height       conf  \
# 0            2   238   200     92     116  49.230339
# 1            2   426   239    278      66  66.124664
# 2            3   377   319     71      19  87.236626
# 3            3   453   319     52      19  93.294891
# 4            3   509   313    111      23  85.986351
# ..         ...   ...   ...    ...     ...        ...
# 216         10   443  1209     60      51  88.553131
# 217         13  1469  1428    -14      60  77.925272
# 218         16  1271  1638    234      26  96.546208
# 219         18   235  1675    637     232  91.829305
# 220         19   522  1916    413      23  96.433813
#
#                                                   text
# 0                                                    S
# 1                                                pAyYs
# 2                                              #27,2nd
# 3                                               Cross,
# 4                                            MSRamaiah
# ..                                                 ...
# 216                                        Tax% 28.00
# 217                                   2,950 ‘ForDAYS.
# 218                              Authorised Signature
# 219  Terms and Conditions: 1 Allcontents/ charges o...
# 220                             Save Paper Save Earth
#
# [221 rows x 7 columns]

# %%
print(df["text"].to_numpy())
# Out:
# ['S' 'pAyYs' '#27,2nd' 'Cross,' 'MSRamaiah' 'Enclave,' 'Havanur'
#  'Layout,Nagasandra' 'Post,Bangalore' '560073' 'Karnataka' 'Cell'
#  ':9341066551' '~' 'E-Mail' 'ID:' 'dayscoffee2012@qmail.' 'com' '-TIN-'
#  '29481209435,' 'Dated' ':' '30-03-2014' 'GST' 'NO' '>29AAKFD3444R1Z0'
#  'Buyer' 'State' 'Code' ':' '29,' 'KARNATAKA' 'M/s.' 'Tally' 'Solutions'
#  'Pvt' 'Ltd.,' 'PAN:' 'AAKFD3444R.' 'AMR' 'Tech' 'Park,' '2B,' 'Corporate'
#  'Block' 'GST' 'No' '-' '29AAKFD3444R1ZQ' '2nd' 'Floor,' 'Hosur' 'Main'
#  'Road,' 'Bengalooru,' 'Karnataka' 'GST' 'No' ':' '29AAACP7879D1Z0'
#  'State' 'Code:' '29' 'Invoice' '#:-' 'Date:' '__.31stJan-2023' '[sis|'
#  'Taras' '[ewe]' '“ony' 'Uae' '|' 'ate' 'Amt' 'Toa' '[TART' 'Toa' 'Jan-23'
#  'Beans' 'Additional' 'Flavoured' 'tea' '-.Gngr' '&' 'Cardm' '.' '|Assam'
#  '&' 'Plain' 'tea' 'Green' 'Tea' '-' 'Verities' 'Lemon' 'Premix' 'Badam'
#  'Tomato' 'Soup' 'Sugar' 'Wodden' 'Stirrers' 'Horlicks' 'Boost.' 'Milk'
#  '(Nandini)' 'eooc0eocooeoscoCoSo' 'Tax%' '28.00' '2,950' '‘ForDAYS.'
#  'Authorised' 'Signature' 'Terms' 'and' 'Conditions:' '1' 'Allcontents/'
#  'charges' 'of' 'the' 'invoice' 'will' 'be' 'deemed' 'correct' '&'
#  'accepted' 'by' 'you,' 'unless' 'you' 'inform' 'us' 'of' 'any'
#  'discrepancies/' 'disagreement' 'through' 'a' 'signed' 'letter,' 'within'
#  '30' 'days' 'from' 'the' 'date' 'of' 'receipt' 'of' 'invoice,' 'falling'
#  'which' 'it' 'shall' 'be' 'construed' 'that' 'all' 'contents/' 'charges'
#  'indicated' 'in' 'the' 'invoice' 'is' 'in' 'order' '&' 'DAY' 'S' 'ABCTCL'
#  'will' 'not' 'be' 'responsible' 'or' 'liable' 'for' 'any' 'disputes/'
#  'claims' 'received' 'post' 'the' 'said' 'date.' '‘Goods' 'once' 'sold'
#  'cannot' 'be' 'either' 'exchanged' 'or' 'taken' 'back' '‘This'
#  'transaction' 'is' 'subject' 'to' 'Bengalooru' '-' 'Court' 'Jurisdiction'
#  'only.' 'Save' 'Paper' 'Save' 'Earth' 'S pAyYs '
#  '#27,2nd Cross, MSRamaiah Enclave, Havanur Layout,Nagasandra Post,Bangalore 560073 Karnataka Cell :9341066551 ~ E-Mail ID: dayscoffee2012@qmail. com -TIN- 29481209435, Dated : 30-03-2014 GST NO >29AAKFD3444R1Z0 Buyer State Code : 29, KARNATAKA M/s. Tally Solutions Pvt Ltd., PAN: AAKFD3444R. AMR Tech Park, 2B, Corporate Block GST No - 29AAKFD3444R1ZQ 2nd Floor, Hosur Main Road, Bengalooru, Karnataka GST No : 29AAACP7879D1Z0 State Code: 29 Invoice #:- Date: __.31stJan-2023 [sis| Taras [ewe] “ony Uae | ate Amt Toa [TART Toa '
#  'Jan-23 Beans Additional Flavoured tea -.Gngr & Cardm . |Assam & Plain tea Green Tea - Verities Lemon Premix Badam Tomato Soup Sugar Wodden Stirrers Horlicks Boost. Milk (Nandini) '
#  'Tax% 28.00 ' '2,950 ‘ForDAYS. ' 'Authorised Signature '
#  'Terms and Conditions: 1 Allcontents/ charges of the invoice will be deemed correct & accepted by you, unless you inform us of any discrepancies/ disagreement through a signed letter, within 30 days from the date of receipt of invoice, falling which it shall be construed that all contents/ charges indicated in the invoice is in order & DAY S ABCTCL will not be responsible or liable for any disputes/ claims received post the said date. ‘Goods once sold cannot be either exchanged or taken back ‘This transaction is subject to Bengalooru - Court Jurisdiction only. '
#  'Save Paper Save Earth ']

# %%
df.reset_index(inplace=True)
df.drop(columns=["index"], inplace=True)

# %%
df
# Out:
#      block_num  left   top  width  height       conf  \
# 0            2   238   200     92     116  49.230339
# 1            2   426   239    278      66  66.124664
# 2            3   377   319     71      19  87.236626
# 3            3   453   319     52      19  93.294891
# 4            3   509   313    111      23  85.986351
# ..         ...   ...   ...    ...     ...        ...
# 216         10   443  1209     60      51  88.553131
# 217         13  1469  1428    -14      60  77.925272
# 218         16  1271  1638    234      26  96.546208
# 219         18   235  1675    637     232  91.829305
# 220         19   522  1916    413      23  96.433813
#
#                                                   text
# 0                                                    S
# 1                                                pAyYs
# 2                                              #27,2nd
# 3                                               Cross,
# 4                                            MSRamaiah
# ..                                                 ...
# 216                                        Tax% 28.00
# 217                                   2,950 ‘ForDAYS.
# 218                              Authorised Signature
# 219  Terms and Conditions: 1 Allcontents/ charges o...
# 220                             Save Paper Save Earth
#
# [221 rows x 7 columns]

# %%
df["x"] = df["left"] + df["width"] 
df["y"] = df["top"] + df["height"]

# %%
df["PageHeight"] = preProcessedImage.shape[0]
df["PageWidth"] = preProcessedImage.shape[1]

# %%
df
# Out:
#      block_num  left   top  width  height       conf  \
# 0            2   238   200     92     116  49.230339
# 1            2   426   239    278      66  66.124664
# 2            3   377   319     71      19  87.236626
# 3            3   453   319     52      19  93.294891
# 4            3   509   313    111      23  85.986351
# ..         ...   ...   ...    ...     ...        ...
# 216         10   443  1209     60      51  88.553131
# 217         13  1469  1428    -14      60  77.925272
# 218         16  1271  1638    234      26  96.546208
# 219         18   235  1675    637     232  91.829305
# 220         19   522  1916    413      23  96.433813
#
#                                                   text     x     y  \
# 0                                                    S   330   316
# 1                                                pAyYs   704   305
# 2                                              #27,2nd   448   338
# 3                                               Cross,   505   338
# 4                                            MSRamaiah   620   336
# ..                                                 ...   ...   ...
# 216                                        Tax% 28.00    503  1260
# 217                                   2,950 ‘ForDAYS.   1455  1488
# 218                              Authorised Signature   1505  1664
# 219  Terms and Conditions: 1 Allcontents/ charges o...   872  1907
# 220                             Save Paper Save Earth    935  1939
#
#      PageHeight  PageWidth
# 0          2200       1700
# 1          2200       1700
# 2          2200       1700
# 3          2200       1700
# 4          2200       1700
# ..          ...        ...
# 216        2200       1700
# 217        2200       1700
# 218        2200       1700
# 219        2200       1700
# 220        2200       1700
#
# [221 rows x 11 columns]

# %%
dateDF = df.copy()

# %%
dateDF
# Out:
#      block_num  left   top  width  height       conf  \
# 0            2   238   200     92     116  49.230339
# 1            2   426   239    278      66  66.124664
# 2            3   377   319     71      19  87.236626
# 3            3   453   319     52      19  93.294891
# 4            3   509   313    111      23  85.986351
# ..         ...   ...   ...    ...     ...        ...
# 216         10   443  1209     60      51  88.553131
# 217         13  1469  1428    -14      60  77.925272
# 218         16  1271  1638    234      26  96.546208
# 219         18   235  1675    637     232  91.829305
# 220         19   522  1916    413      23  96.433813
#
#                                                   text     x     y  \
# 0                                                    S   330   316
# 1                                                pAyYs   704   305
# 2                                              #27,2nd   448   338
# 3                                               Cross,   505   338
# 4                                            MSRamaiah   620   336
# ..                                                 ...   ...   ...
# 216                                        Tax% 28.00    503  1260
# 217                                   2,950 ‘ForDAYS.   1455  1488
# 218                              Authorised Signature   1505  1664
# 219  Terms and Conditions: 1 Allcontents/ charges o...   872  1907
# 220                             Save Paper Save Earth    935  1939
#
#      PageHeight  PageWidth
# 0          2200       1700
# 1          2200       1700
# 2          2200       1700
# 3          2200       1700
# 4          2200       1700
# ..          ...        ...
# 216        2200       1700
# 217        2200       1700
# 218        2200       1700
# 219        2200       1700
# 220        2200       1700
#
# [221 rows x 11 columns]

# %%
for index in dateDF.index:
    text = dateDF["text"][index]
    dateDF["text"][index] = preProcessText(text)
# Out:
# /tmp/ipykernel_22237/2254876534.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dateDF["text"][index] = preProcessText(text)

# %%
dateDF
# Out:
#      block_num  left   top  width  height       conf  \
# 0            2   238   200     92     116  49.230339
# 1            2   426   239    278      66  66.124664
# 2            3   377   319     71      19  87.236626
# 3            3   453   319     52      19  93.294891
# 4            3   509   313    111      23  85.986351
# ..         ...   ...   ...    ...     ...        ...
# 216         10   443  1209     60      51  88.553131
# 217         13  1469  1428    -14      60  77.925272
# 218         16  1271  1638    234      26  96.546208
# 219         18   235  1675    637     232  91.829305
# 220         19   522  1916    413      23  96.433813
#
#                                                   text     x     y  \
# 0                                                        330   316
# 1                                                 payy   704   305
# 2                                                #27-2   448   338
# 3                                                   co   505   338
# 4                                               mamaia   620   336
# ..                                                 ...   ...   ...
# 216                                          ax%-28-00   503  1260
# 217                                        2-950-‘foay  1455  1488
# 218                                        auoie-igaue  1505  1664
# 219  em-a-coiio-1-allcoe-cage-of-e-ivoice-will-be-e...   872  1907
# 220                                    ave-pape-ave-ea   935  1939
#
#      PageHeight  PageWidth
# 0          2200       1700
# 1          2200       1700
# 2          2200       1700
# 3          2200       1700
# 4          2200       1700
# ..          ...        ...
# 216        2200       1700
# 217        2200       1700
# 218        2200       1700
# 219        2200       1700
# 220        2200       1700
#
# [221 rows x 11 columns]

# %%
dates = []
for index in dateDF.index:
    text = dateDF["text"][index]
    if verifyDate(text):
        dates.append(text)
# Out:
# payy
# #27-2
# co
# mamaia
# eclave
# avau
# layou-agaaa
# po-bagaloe
# 560073
# kaaaka
# cell
# 9341066551
# ~
# e-mail
# i
# aycoffee2012@qmail
# com
# i
# 29481209435
# ae
#
# 30-03-2014
# g
# o
# >29aakf34441z0
# buye
# ae
# coe
#
# 29
# kaaaka
# m
# ally
# oluio
# pv
# l
# pa
# aakf3444
# am
# ec
# pak
# 2b
# copoae
# block
# g
# o
#
# 29aakf34441zq
# 2
# floo
# ou
# mai
# oa
# begaloou
# kaaaka
# g
# o
#
# 29aaacp78791z0
# ae
# coe
# 29
# ivoice
# #
# ae
# __-31ja-2023
# [i|
# aa
# [ewe]
# “oy
# uae
# |
# ae
# am
# oa
# [a
# oa
# 07-23
# bea
# aiioal
# flavoue
# ea
# gg
# &
# cam
#
# |aam
# &
# plai
# ea
# gee
# ea
#
# veiie
# lemo
# pemix
# baam
# omao
# oup
# uga
# woe
# ie
# olick
# boo
# milk
# (aii)
# eooc0eocooeococoo
# ax%
# 28-00
# 2-950
# ‘foay
# auoie
# igaue
# em
# a
# coiio
# 1
# allcoe
# cage
# of
# e
# ivoice
# will
# be
# eeme
# coec
# &
# accepe
# by
# you
# ule
# you
# ifom
# u
# of
# ay
# icepacie
# iageeme
# oug
# a
# ige
# lee
# wii
# 30
# ay
# fom
# e
# ae
# of
# eceip
# of
# ivoice
# fallig
# wic
# i
# all
# be
# coue
# a
# all
# coe
# cage
# iicae
# i
# e
# ivoice
# i
# i
# oe
# &
# ay
#
# abccl
# will
# o
# be
# epoible
# o
# liable
# fo
# ay
# ipue
# claim
# eceive
# po
# e
# ai
# ae
# ‘goo
# oce
# ol
# cao
# be
# eie
# excage
# o
# ake
# back
# ‘i
# aacio
# i
# ubjec
# o
# begaloou
#
# cou
# juiicio
# oly
# ave
# pape
# ave
# ea
# payy
# #27-2-co-mamaia-eclave-avau-layou-agaaa-po-bagaloe-560073-kaaaka-cell-9341066551-~-e-mail-i-aycoffee2012@qmail-com-i-29481209435-ae--30-03-2014-g-o->29aakf34441z0-buye-ae-coe--29-kaaaka-m--ally-oluio-pv-l--pa-aakf3444-am-ec-pak-2b-copoae-block-g-o--29aakf34441zq-2-floo-ou-mai-oa-begaloou-kaaaka-g-o--29aaacp78791z0-ae-coe-29-ivoice-#--ae-__-31ja-2023-[i|-aa-[ewe]-“oy-uae-|-ae-am-oa-[a-oa
# 07-23-bea-aiioal-flavoue-ea--gg-&-cam--|aam-&-plai-ea-gee-ea--veiie-lemo-pemix-baam-omao-oup-uga-woe-ie-olick-boo-milk-(aii)
# ax%-28-00
# 2-950-‘foay
# auoie-igaue
# em-a-coiio-1-allcoe-cage-of-e-ivoice-will-be-eeme-coec-&-accepe-by-you-ule-you-ifom-u-of-ay-icepacie-iageeme-oug-a-ige-lee-wii-30-ay-fom-e-ae-of-eceip-of-ivoice-fallig-wic-i-all-be-coue-a-all-coe-cage-iicae-i-e-ivoice-i-i-oe-&-ay--abccl-will-o-be-epoible-o-liable-fo-ay-ipue-claim-eceive-po-e-ai-ae-‘goo-oce-ol-cao-be-eie-excage-o-ake-back-‘i-aacio-i-ubjec-o-begaloou--cou-juiicio-oly
# ave-pape-ave-ea

# %%
dates
# Out:
# ['30-03-2014']

# %%
dateDF[dateDF["text"] == dates[1]]

# %%
df

# %%
neighbourFields = ["date", "dated", "invoice", "delivery", "order", "due", "payment", "tax", "bill", "receipt", "issue"]

# %%
def createColumn(df, list):
    for col in list:
        df[col]=0

# %%
createColumn(df, neighbourFields)

# %%
df

# %%
def returnDist(x1, y1, x2, y2):
    p = [x1, y1]
    q = [x2, y2]
    return math.dist(p, q)

# %%
for index in df.index:
    x1 = df["x"][index]//df["PageWidth"][index]
    y1 = df["y"][index]//df["PageHeight"][index]

# %%
d = df[df.index==30]

# %%
d

# %%
x1 = d["x"][30]/d["PageWidth"][30]
y1 = d["y"][30]/d["PageHeight"][30]
block = d["block_num"][30]
x1

# %%
neighbours = {}
for index in df.index:
    x2 = df["x"][index]/df["PageWidth"][index]
    y2 = df["y"][index]/df["PageHeight"][index]
    dist = returnDist(x1, y1, x2, y2)
    if dist!=0 and dist<=0.2:
        neighbours[df["text"][index]]=dist

# %%
neighbours

# %%
lineNeighbours = []
for index in df.index:
    x2 = df["x"][index]/df["PageWidth"][index]
    y2 = df["y"][index]/df["PageHeight"][index]
    blockN = df["block_num"][index]
    if abs(y1-y2)<0.2 and abs(blockN-block)<=1:
        lineNeighbours.append(df["text"][index])

# %%
lineNeighbours

# %%
def allocateNeighbours(df, neighbourFields):
    for index in df.index:
        x1 = df["x"][index]
        y1 = df["y"][index]
        block = df["block_num"][index]
        para = df["par_num"][index]
        neighbours = []
        for index2 in df.index:
            x2 = df["x"][index2]
            y2 = df["y"][index2]
            block2 = df["block_num"][index2]
            para2 = df["par_num"][index2]
            dist = returnDist(x1, y1, x2, y2)
            if dist<100:
                neighbours.append(df["text"][index2].lower())
            if abs(y1-y2)<50 and (x2-x1)<10 and abs(block2-block)<=1 and abs(para2==para)<=1:
                neighbours.append(df["text"][index2].lower())
        for n in neighbourFields:
            if n in neighbours:
                df[n][index]=1

# %%
allocateNeighbours(df, neighbourFields)

# %%
df.describe()

# %%
dates

# %%
indexes = []
for date in dates:
    i = dateDF[dateDF["text"]==date].index
    for index in i:
        indexes.append(index)
indexes

# %%
resultDF=df.copy()

# %%
indexesToDrop=[]
for index in resultDF.index:
    if index not in indexes:
        indexesToDrop.append(index)
resultDF.drop(indexesToDrop, inplace=True)

# %%
resultDF
