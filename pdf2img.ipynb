# %%
# !pip install pdf2img

# %%
# !pip install PyPDF2

# %%
# !pip install pdf2jpg

# %%
import os
import pdf2image
from pdf2image import convert_from_path
import cv2
import matplotlib.pyplot as plt
import PyPDF2
import PIL
from PIL import Image, ImageTk
import numpy as np
from pdf2jpg import pdf2jpg

# %%
pdfPath = os.path.join("Data", "DocumentAI")
print(pdfPath)
# Out:
# Data/DocumentAI

# %%
imagesPath = os.path.join("Data", "Images")
print(imagesPath)
# Out:
# Data/Images

# %%
if not os.path.exists(imagesPath):
    if os.name=="posix":
        # !mkdir -p {imagesPath}
    elif os.name=="nt":
        # !mkdir {imagesPath}
# Out:
# /bin/bash: /home/aman/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
imagesPath = os.path.join("Data", "images")
print(imagesPath)
# Out:
# Data/images

# %%
if not os.path.exists(imagesPath):
    if os.name=="posix":
        # !mkdir -p {imagesPath}
    elif os.name=="nt":
        # !mkdir {imagesPath}
# Out:
# /bin/bash: /home/aman/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
dir = os.listdir(pdfPath)

# %%
len(dir)
# Out:
# 95

# %%
for file in dir:
    split_tup = os.path.splitext(file)
    if split_tup[1] and split_tup[1]==".pdf":
        filePath = os.path.join(pdfPath, file)
        result = pdf2jpg.convert_pdf2jpg(filePath,imagesPath, pages="ALL")
# Out:
# Jun 19, 2023 1:39:49 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Jun 19, 2023 1:39:49 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Jun 19, 2023 1:39:50 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider addType1Font
# SEVERE: Could not load font file: /usr/share/fonts/X11/Type1/P052-Italic.pfb
# java.io.IOException: Start marker missing
# 	at org.apache.fontbox.pfb.PfbParser.parsePfb(PfbParser.java:131)
# 	at org.apache.fontbox.pfb.PfbParser.<init>(PfbParser.java:102)
# 	at org.apache.fontbox.type1.Type1Font.createWithPFB(Type1Font.java:54)
# 	at org.apache.pdfbox.pdmodel.font.FileSystemFontProvider.addType1Font(FileSystemFontProvider.java:646)
# 	at org.apache.pdfbox.pdmodel.font.FileSystemFontProvider.scanFonts(FileSystemFontProvider.java:255)
# ...

# %%
os.chdir("/home/aman/Documents/Tally/Git-Document-AI/Document-AI/Data/images/")

# %%
dirs = os.listdir("/home/aman/Documents/Tally/Git-Document-AI/Document-AI/Data/images/")

# %%
imgList = []
for dir in dirs:
    images = os.listdir(dir)
    image = images[0]
    imagePath = dir+"/"+image
    image = cv2.imread(imagePath)
    imgList.append(image)

# %%
imageList=[]
for img in imgList:
    i=np.array(img[0])
    imageList.append(i)

# %%
os.chdir("/home/aman/Documents/Tally/Git-Document-AI/Document-AI/Data/Images/")

# %%
i=0
for img in imgList:
    i+=1
    image = Image.fromarray(img, "RGB")
    image_filename = str(i)+".jpeg"
    image.save(image_filename)
last = i

# %%
os.chdir("/home/aman/Documents/Tally/Git-Document-AI/Document-AI/Data/DocumentAI/")

# %%
dir = os.listdir("/home/aman/Documents/Tally/Git-Document-AI/Document-AI/Data/DocumentAI/")

# %%
imgList=[]
for file in dir:
    split_tup = os.path.splitext(file)
    if split_tup[1] and split_tup[1]==".jpeg":
        filePath = os.path.join(file)
        image = cv2.imread(filePath)
        imgList.append(image)
    elif split_tup[1] and split_tup[1]==".jpg":
        filePath = os.path.join(file)
        image = cv2.imread(filePath)
        imgList.append(image)

# %%
imageList=[]
for img in imgList:
    i=np.array(img[0])
    imageList.append(i)

# %%
len(imageList)
# Out:
# 10

# %%
os.chdir("/home/aman/Documents/Tally/Git-Document-AI/Document-AI/Data/Images/")

# %%
for img in imgList:
    last+=1
    image = Image.fromarray(img, "RGB")
    image_filename = str(last)+".jpeg"
    image.save(image_filename)
