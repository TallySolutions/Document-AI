# %%
import cv2
import matplotlib.pyplot as plt
import os
import warnings
warnings.filterwarnings("ignore")
import pytesseract
from pytesseract import Output
pytesseract.pytesseract.tesseract_cmd="/home/aman/anaconda3/envs/tallyInvoiceParser.env/bin/tesseract"
os.environ['TESSDATA_PREFIX'] = "/home/aman/anaconda3/envs/tallyInvoiceParser.env/share/tessdata"
from PIL import Image, ImageTk
import numpy as np

# %%
# imagesFolderPath = '/home/aman/Documents/Tally/Git-Document-AI/Document-AI/Data/Images/'
# os.chdir(imagesFolderPath)
# imageNames = os.listdir(imagesFolderPath)
# imagePath = "76.jpeg"
# image = cv2.imread(imagePath)
# plt.imshow(image)

# %%
# data = pytesseract.image_to_data(image, output_type=Output.DATAFRAME)
# data.dropna(inplace=True)
# indexesToDrop = []
# stopwords = ["", " ", "  ", "/", ":", "-", ".", ",", "\n", "\t", "\\", "(", ")", "[", "]", "{", "}", "*", "&", "%", "$", "#", "|"]
# for index in data.index:
#     if data["text"][index] in stopwords:
#         indexesToDrop.append(index)   
# data.drop(indexesToDrop, inplace=True)
# data.reset_index(inplace=True)
# data.drop(columns=["index"], inplace=True)
# for index in data.index:
#     data["text"][index] = str(data["text"][index])
# data["right"] = data["left"] + data["width"]
# data["bottom"] = data["top"] + data["height"]
# data.head()
# Out:
#    level  page_num  block_num  par_num  line_num  word_num  left  top  width  \
# 0      5         1          1        1         1         1   281   53    170
# 1      5         1          1        1         1         2   465   53    103
# 2      5         1          1        1         2         1   336  101    164
# 3      5         1          1        1         3         1   338  152    169
# 4      5         1          1        1         4         1   338  206    169
#
#    height       conf      text  right  bottom
# 0      37  96.209427   Company    451      90
# 1      29  96.560120      Name    568      82
# 2      30  87.726646  Address1    500     131
# 3      30  92.734245  Address2    507     182
# 4      30  91.988770  Address3    507     236

# %%
# L = data["left"].to_numpy()
# T = data["top"].to_numpy()
# R = data["right"].to_numpy()
# B = data["bottom"].to_numpy()

# BB = [[max(min(L)-40, 0), max(min(T)-40, 0)], [min(max(R)+40, image.shape[1]), min(max(B)+40, image.shape[0])]]

# %%
# ROI = image.copy()
# ROI = cv2.rectangle(ROI, BB[0], BB[1], (0, 255, 0), 10)
# plt.imshow(ROI)

# %%
# croppedImage = image[BB[0][1]:BB[1][1], BB[0][0]:BB[1][0]]
# plt.imshow(croppedImage)
# croppedImage.shape
# Out:
# (1954, 864, 3)

# %%
# cropped = Image.fromarray(croppedImage)
# type(cropped)
# Out:
# PIL.Image.Image

# %%
# cropped = cropped.resize((1000, 1000))

# %%
# plt.imshow(cropped)

# %%
# img = np.array(cropped)
# gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
# blur = cv2.GaussianBlur(gray, (3,3),1)
# threshold_img = cv2.adaptiveThreshold(blur,255,1,1,9,10)

# %%
# plt.imshow(threshold_img, cmap="gray")

# %%
# text = pytesseract.image_to_data(cropped, output_type=Output.DATAFRAME)
# text.dropna(inplace=True)
# print(text["text"].to_numpy())
# Out:
# ['Company' 'Name' 'Addressi1' 'Address2' 'Address3s' 'Address4'
#  'GSTIN-:--' 'BIA' 'AA4SA1234A12Z5' 'CIN' 'NO:' 'TAX' 'INVOICE' 'Bill'
#  'No:-' 'S22/15' 'Date' '04/11/2022' ' ' 'Cust.' 'Name:' 'rahul-rahul'
#  'Cust' 'GSTIN:' '29A0UPB3384A12Z2W' ' ' ' ' ' ' 'Sri' 'Item' 'Desc'
#  'HSN/SAC' 'Qaty.' 'Rate' 'Amount' '1' 'MENS' '1' '1499.' '1499.00'
#  'SHIRTS' 'CGSGST' '@GIY.00' 'UT/' 'SSGST@I.00' 'Dis%' 'Oo' '2' 'MENS' '4'
#  '1499.' '1499.00' 'TROUSER' 'CGST' '@Y9.00' 'UT/' 'SGST@I.00' 'Dis%'
#  'te}' '3' '1001-0110-' '1' '240.9' '240.90' 'ASSTD' 'CGSGST' '@2.50'
#  'UT/' 'SSGST@Oo.00' 'Dis%' 'te}' '4' 'MENS' '4' '1499.' '1499.00' 'JEANS'
#  'CGST' '@Y.00' 'UT/' 'SGSGST@I.00' 'Dis%' 'te}']

# %%
def preProcessImage(image):
    data = pytesseract.image_to_data(image, output_type=Output.DATAFRAME)
    data.dropna(inplace=True)
    indexesToDrop = []
    stopwords = ["", " ", "  ", "/", ":", "-", ".", ",", "\n", "\t", "\\", "(", ")", "[", "]", "{", "}", "*", "&", "%", "$", "#", "|"]
    for index in data.index:
        if data["text"][index] in stopwords:
            indexesToDrop.append(index)   
    data.drop(indexesToDrop, inplace=True)
    data.reset_index(inplace=True)
    data.drop(columns=["index"], inplace=True)
    for index in data.index:
        data["text"][index] = str(data["text"][index])
    data["right"] = data["left"] + data["width"]
    data["bottom"] = data["top"] + data["height"]

    L = data["left"].to_numpy()
    T = data["top"].to_numpy()
    R = data["right"].to_numpy()
    B = data["bottom"].to_numpy()
    
    BB = [[max(min(L)-40, 0), max(min(T)-40, 0)], [min(max(R)+40, image.shape[1]), min(max(B)+40, image.shape[0])]]

    croppedImage = image[BB[0][1]:BB[1][1], BB[0][0]:BB[1][0]]
    cropped = Image.fromarray(croppedImage)
    cropped = cropped.resize((1000, 1000))

    img = np.array(cropped)
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    blur = cv2.GaussianBlur(gray, (3,3),1)
    threshold_img = cv2.adaptiveThreshold(blur,255,1,1,9,10)

    return threshold_img
